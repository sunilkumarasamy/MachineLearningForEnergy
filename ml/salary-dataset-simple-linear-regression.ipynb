# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../input/salary-dataset-simple-linear-regression/Salary_dataset.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0

# %%
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
#validate missing values
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
sns.regplot(x=df['YearsExperience'], y=df['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.scatterplot(df,x="Salary",y="YearsExperience")
# Out:
# <Axes: xlabel='Salary', ylabel='YearsExperience'>

# %%
df.drop("Unnamed: 0",inplace=True,axis=1)

# %%
df.head(2)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0

# %%
#Visualizing Data Distributions
plt.figure(figsize=(8, 6))
sns.histplot(df['Salary'], bins=20, color='blue')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Distribution of Salary')
plt.show()

# %%
#show statistic
df.describe(include='all')
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
# correlation plot
corr = df.corr()
sns.heatmap(corr, cmap = 'Wistia', annot= True);

# %%
#declare features vector and target
x = df[['YearsExperience']]
y = df['Salary']

# %%
#using sklearn for linear regression
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
#making prediction
y_pred = reg.predict(x)

# %%
print("R-squared:",reg.score(x, y).round(3))
# Out:
# R-squared: 0.957

# %%
print("Coefficient:",reg.coef_[0].round(3))
# Out:
# Coefficient: 9449.962

# %%
print("Intercept:",reg.intercept_.round(3))
# Out:
# Intercept: 24848.204

# %%
#using module statmodel to show statistic
model = sm.OLS(y, sm.add_constant(x))
results = model.fit()
b, m = results.params

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Tue, 19 Sep 2023   Prob (F-statistic):           1.14e-20
# Time:                        14:20:58   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            2.485e+04   2306.654     10.772      0.000    2.01e+04    2.96e+04
# YearsExperience  9449.9623    378.755     24.950      0.000    8674.119    1.02e+04
# ==============================================================================
# Omnibus:                        2.140   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.569
# Skew:                           0.363   Prob(JB):                        0.456
# Kurtosis:                       2.147   Cond. No.                         13.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#plot linear regression
plt.title("Salary with Years Experience")
plt.xlabel("Years Experience")
plt.ylabel("Salary")
plt.scatter(x, y, alpha = 0.2, color="blue")
plt.plot(x, y_pred, color="black")
plt.show()

# %%
df['Prediction'] = y_pred.round(1)
df['Residual'] = y - y_pred.round(1)
df['Difference%'] = (np.absolute(df['Residual'] / df['Salary'] * 100)).round(2)
df
# Out:
#     YearsExperience    Salary  Prediction  Residual  Difference%
# 0               1.2   39344.0     36188.2    3155.8         8.02
# 1               1.4   46206.0     38078.2    8127.8        17.59
# 2               1.6   37732.0     39968.1   -2236.1         5.93
# 3               2.1   43526.0     44693.1   -1167.1         2.68
# 4               2.3   39892.0     46583.1   -6691.1        16.77
# 5               3.0   56643.0     53198.1    3444.9         6.08
# 6               3.1   60151.0     54143.1    6007.9         9.99
# 7               3.3   54446.0     56033.1   -1587.1         2.91
# 8               3.3   64446.0     56033.1    8412.9        13.05
# 9               3.8   57190.0     60758.1   -3568.1         6.24
# 10              4.0   63219.0     62648.1     570.9         0.90
# 11              4.1   55795.0     63593.0   -7798.0        13.98
# 12              4.1   56958.0     63593.0   -6635.0        11.65
# 13              4.2   57082.0     64538.0   -7456.0        13.06
# 14              4.6   61112.0     68318.0   -7206.0        11.79
# 15              5.0   67939.0     72098.0   -4159.0         6.12
# 16              5.2   66030.0     73988.0   -7958.0        12.05
# 17              5.4   83089.0     75878.0    7211.0         8.68
# 18              6.0   81364.0     81548.0    -184.0         0.23
# 19              6.1   93941.0     82493.0   11448.0        12.19
# 20              6.9   91739.0     90052.9    1686.1         1.84
# 21              7.2   98274.0     92887.9    5386.1         5.48
# 22              8.0  101303.0    100447.9     855.1         0.84
# 23              8.3  113813.0    103282.9   10530.1         9.25
# 24              8.8  109432.0    108007.9    1424.1         1.30
# 25              9.1  105583.0    110842.9   -5259.9         4.98
# 26              9.6  116970.0    115567.8    1402.2         1.20
# 27              9.7  112636.0    116512.8   -3876.8         3.44
# 28             10.4  122392.0    123127.8    -735.8         0.60
# 29             10.6  121873.0    125017.8   -3144.8         2.58

# %%
df.describe()
# Out:
#        YearsExperience         Salary     Prediction      Residual  \
# count        30.000000      30.000000      30.000000     30.000000
# mean          5.413333   76004.000000   76003.996667      0.003333
# std           2.837888   27414.429785   26817.931561   5687.626567
# min           1.200000   37732.000000   36188.200000  -7958.000000
# 25%           3.300000   56721.750000   56033.100000  -4088.450000
# 50%           4.800000   65238.000000   70208.000000   -459.900000
# 75%           7.800000  100545.750000   98557.900000   3372.625000
# max          10.600000  122392.000000  125017.800000  11448.000000
#
#        Difference%
# count    30.000000
# mean      7.047333
# std       5.174505
# min       0.230000
# 25%       2.605000
# 50%       6.100000
# 75%      11.755000
# max      17.590000
